# %%
# %%capture
# Setup
# %pip install virtualenv
# !virtualenv venv
# !source venv/bin/activate
# %pip install -r ../cr_extraction/requirements.txt
# %pip install python-dotenv
# %pip install tiktoken
# %pip install pandas

# %%
import requests
from pdf2image import convert_from_bytes
import pytesseract
import io
from urllib.parse import unquote
import tiktoken
from typing import Tuple
import urllib.parse
import pandas as pd

# %%
# CONSTANTS
OPENAI_MODEL = "gpt-3.5-turbo-1106"

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
from PIL import Image
from reportlab.pdfgen import canvas


# Check if the file is a TIFF
def tiff_to_PDF(image):
    # Create a new PDF file
    pdf = canvas.Canvas('output.pdf')
    # Draw the image on the PDF, resizing it to fit the page
    pdf.drawInlineImage(image, 0, 0, width=595, height=842)  # A4 size

    # Save the PDF
    pdf.save()
    return pdf

# %%
file_path = 'output/ASSEMBLY GmbH_Berlin (Charlottenburg).tiff'

# Open the file using PIL
image = Image.open(file_path)

tiff_to_PDF(image)

# %%
import os
from supabase import create_client, Client
from dotenv import load_dotenv

load_dotenv("../.env")
#get URL from environment variable

url: str = os.environ.get("SUPABASE_URL")
key: str = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(url, key)

# %%
import requests

def write_to_supabase(company: str, file: bytes):
    file_path = "output/Tanso Technologies GmbH_München.pdf"
    bucket_name = "shareholder_documents"
    storage_path = f"{company}/2021_06_01_Tanso Technologies GmbH_Munchen.pdf"

    # Open the file in binary mode
    
    supabase.storage.from_("shareholder_documents").upload(file=file,path=storage_path, file_options={"content-type": "pdf"})

    # save storage path to startup table
    table_name = "startups"
    file_link_column = "link_shareholder_file_2021"

    # Construct the path to the file in Supabase Storage
    file_link = f"https://{bucket_name}.supabase.co/{storage_path}"

    # Define the startup_id
    startup_id = 5

    # Update the table
    response = supabase.table(table_name).update({file_link_column: file_link}).match({'startup_id': startup_id}).execute()

# %%
def parse_filename(encoded_filename):
    """
    This function takes an encoded filename string and returns the decoded filename.
    """
    decoded_filename = encoded_filename
    # The filename is after the "UTF-8''" part, so split on that
    try:
        _, encoded_filename = encoded_filename.split("UTF-8''", 1)

    # Now decode the filename
        decoded_filename = urllib.parse.unquote_plus(encoded_filename)
    except:
        pass
    return decoded_filename

def get_pdf_for_company(company: str, document_type: str, bypass_storage: bool = False) -> Tuple[str, str]:
    # get pdf stream directly 
    file_response = requests.post('https://europe-west3-lumpito.cloudfunctions.net/download_files', json={'company': company, 'documents': [document_type], 'bypass_storage': bypass_storage})
    # Make sure the request was successful
    if file_response.status_code == 200:
        
        # Try to extract filename from the Content-Disposition header
        content_disposition = file_response.headers.get('Content-Disposition', '')
        if 'attachment; filename=' in content_disposition:
            # Extract filename from Content-Disposition header
            filename = content_disposition.split('filename=')[1]
            # Remove any quotes around the filename
            if '"' in filename or "'" in filename:
                filename = parse_filename(filename.strip("\"'"))
        else:
            mime_type = file_response.headers.get('Content-Type')
            # If the filename is not in the header or you want to set a default
            filename = f'default_filename.{mime_type.split("/")[1]}'

        # Write the PDF binary to a file with the obtained filename
        #write_to_supabase(company,file_response.content)
        with open("output/" + filename, 'wb') as f:
            f.write(file_response.content)
            
        
        return filename, file_response.content
    else:
        print(f'Failed to retrieve PDF: Status code {file_response.status_code}')

# %%
file_name, file_content = get_pdf_for_company('Tanso', 'gs', True)
print(file_name)
print(file_content)
# Out:
# Tanso Technologies GmbH_München.pdf
# b'%PDF-1.4\r%\xe2\xe3\xcf\xd3\r\n1 0 obj\r<</Contents[17 0 R]/CropBox[0 0 595.32 841.92]/MediaBox[0 0 595.32 841.92]/Parent 20 0 R/Resources 2 0 R/Rotate 0/Type/Page>>\rendobj\r2 0 obj\r<</ColorSpace<</DefaultRGB 28 0 R>>/Font<</F1 30 0 R/F2 29 0 R/F3 3 0 R/F4 4 0 R>>>>\rendobj\r3 0 obj\r<</BaseFont/CIDFont+F3/DescendantFonts[<</BaseFont/CIDFont+F3/CIDSystemInfo<</Ordering 11 0 R/Registry 12 0 R/Supplement 0>>/CIDToGIDMap/Identity/FontDescriptor<</Ascent 905/CapHeight 715/Descent -211/Flags 6/FontBBox 13 0 R/FontFile2 19 0 R/FontName/CIDFont+F3/ItalicAngle 0/StemV 14 0 R/Type/FontDescriptor>>/Subtype/CIDFontType2/Type/Font/W 15 0 R>>]/Encoding/Identity-H/Subtype/Type0/ToUnicode 16 0 R/Type/Font>>\rendobj\r4 0 obj\r<</BaseFont/CIDFont+F4/DescendantFonts[<</BaseFont/CIDFont+F4/CIDSystemInfo<</Ordering 5 0 R/Registry 6 0 R/Supplement 0>>/CIDToGIDMap/Identity/FontDescriptor<</Ascent 905/CapHeight 715/Descent -211/Flags 6/FontBBox 7 0 R/FontFile2 18 0 R/FontName/CIDFont+F4/ItalicAngle 0/StemV 8 0 R/Type/FontDescriptor>>/Subtype/CIDFontType2/Type/Font/W 9 0 R>>]/Encoding/Identity-H/Subtype/Type0/ToUnicode 10 0 R/Type/Font>>\rendobj\r5 0 obj\r(Identity)\rendobj\r6 0 obj\r(Adobe)\rendobj\r7 0 obj\r[-666 -211 666 905]\rendobj\r8 0 obj\r666\rendobj\r9 0 obj\r[3 3 277 17 17 277 47 47 610 54 54 666]\rendobj\r10 0 obj\r<</Length 380>>\rstream\n/CIDInit /ProcSet findresource begin 12 dict begin begincmap /CIDSystemInfo << /Registry (Adobe) /Ordering (UCS) /Supplement 0 >> def /CMapName /Adobe-Identity-UCS def /CMapType 2 def 1 begincodespacerange <0000> <FFFF> endcodespacerange 4 beginbfchar <0003> <0020> <0011> <002E> <002F> <004C> <0036> <0053> endbfchar endcmap CMapName currentdict /CMap defineresource pop end end \nendstream\rendobj\r11 0 obj\r(Identity)\rendobj\r12 0 obj\r(Adobe)\rendobj\r13 0 obj\r[-722 -211 722 905]\rendobj\r14 0 obj\r722\rendobj\r15 0 obj\r[3 3 277 16 16 333 17 17 277 18 18 277 36 36 666 39 39 722 43 43 722 51 51 666 68 68 556 69 69 556 70 70 500 72 72 556 74 74 556 75 75 556 76 76 222 78 78 500 79 79 222\n82 82 556 85 85 333 86 86 500 87 87 277 88 88 556 93 93 500]\rendobj\r16 0 obj\r<</Length 647>>\rstream\n/CIDInit /ProcSet findresource begin 12 d
        # The angle is given in degrees counterclockwise, we need to negate it for PIL rotation
        rotation_angle = -osd['rotate']
        if rotation_angle != 0:
            corrected_image = image.rotate(rotation_angle, expand=True)
            return corrected_image
        else:
            return image
    except pytesseract.TesseractError as e:
        print(f"An error occurred during orientation detection: {e}")
        return image

# %%
def pdf_to_text_per_page(pdf_binary):
    # Convert PDF to a list of images
    images = convert_from_bytes(pdf_binary)

    text_content = []

    for i, image in enumerate(images):
        # Correct orientation of the image if necessary
        corrected_image = correct_orientation(image)

        # Use PyTesseract to do OCR on the corrected image
        text = pytesseract.image_to_string(corrected_image)

        # Append the text to the list
        text_content.append(text)

    return text_content

# %% [markdown]
# ## Extracting Structured Data

# %%
from openai import OpenAI
import json
from dotenv import load_dotenv
import os

# Load the environment variables from .env file
load_dotenv("../.env")

client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

# %%
# Define Function Calling



def get_structured_shareholder_list(input_text: str, company_name: str):
    content = f"Here's a shareholders list for ${company_name}: ${input_text} \n Retrieve the shareholders from the shareholders table. "
    messages = [{"role": "user", "content": content }]
    tools = [
        {
            "type": "function",
            "function": {
                "name": "get_shareholders_list",
                "description": "Retrieve the shareholders from the shareholders table",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "shareholders": {
                            "type": "array",
                            "description": "The individual shareholders of the company",
                            "items": {
                                "type": "object",
                                "properties": {
                                    "name": {"type": "string", "description": "First and last name of the shareholder or company name of the shareholder. Do not invent something, double check for correct name"},
                                    "registry_details": {"type": "string", "description": "Registry details of the shareholder, e.g. AG München, HRB 123456"},
                                    "date_of_birth": {"type": "string", "description": "Date of birth of the shareholder"},
                                    "location": {"type": "string", "description": "Location of the shareholder. It is German cities written in German"},
                                    "nominal_value_per_share": {"type": "number", "description": "Nominal value per share in Euro. Usually 1 Euro."},
                                    "total_nominal_value": {"type": "number", "description": "Total nominal value of all shares per shareholder. Usually contains a '€' sign"},
                                    "participation_per_share": {"type": "string", "description": "Participation per share in percent. Is a number value, sometimes with percentag sign. Is the same for all shareholder"},
                                    "total_participation_in_percent": {"type": "string", "description": "Summe der prozentualen Beteiligung des Shareholders"},
                                },
                                "required": ["name", "location", "nominal_value_per_share", "total_nominal_value",  "total_participation_in_percent"],
                            },
                        },
                    },
                },
                "required": ["shareholders"],
            },
        }
    ]
    response = client.chat.completions.create(
        model=OPENAI_MODEL,
        messages=messages,
        tools=tools,
        tool_choice={"type": "function", "function": {"name": "get_shareholders_list"}},
        temperature=0.0,
    )
    response_message = response.choices[0].message
    return response_message


#transform text to json

# %%
# sum up the total participation in percent for all shareholders
total_participation_in_percent = sum([shareholder["total_participation_in_percent"] for shareholder in shareholders["shareholders"]])
total_participation_in_percent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/annabellschafer/Desktop/GitHub/cr_exploration/notebooks/e2e_retrieve_file_get_shareholder_Niklas.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/Users/annabellschafer/Desktop/GitHub/cr_exploration/notebooks/e2e_retrieve_file_get_shareholder_Niklas.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> # sum up the total participation in percent for all shareholders
# ----> <a href='vscode-notebook-cell:/Users/annabellschafer/Desktop/GitHub/cr_exploration/notebooks/e2e_retrieve_file_get_shareholder_Niklas.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> total_participation_in_percent = sum([shareholder["total_participation_in_percent"] for shareholder in shareholders["shareholders"]])
#       <a href='vscode-notebook-cell:/Users/annabellschafer/Desktop/GitHub/cr_exploration/notebooks/e2e_retrieve_file_get_shareholder_Niklas.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> total_participation_in_percent
#
# NameError: name 'shareholders' is not defined

# %%
import contextlib


input_tokens = num_tokens_from_string(contextlib, "cl100k_base")
output_tokens = num_tokens_from_string(response_message.tool_calls[0].function.arguments, "cl100k_base")
cost = input_tokens / 1000 * 0.001 + output_tokens / 1000 * 0.002
cost
# Out:
# 0.0032259999999999997

# %% [markdown]
# ## Final Flow v1

# %%
df = pd.DataFrame()

# %%
file_name, file_content = get_pdf_for_company('Sento', 'gs', True)

# %%
print(file_name)
print(file_content)
# Out:
# sento GmbH_München.pdf
# b'%PDF-1.4\r%\xe2\xe3\xcf\xd3\r\n1 0 obj\r<</Metadata 70 0 R/OutputIntents[72 0 R]/Pages 2 0 R/Type/Catalog>>\rendobj\r2 0 obj\r<</Count 9/Kids[4 0 R 15 0 R 24 0 R 34 0 R 40 0 R 49 0 R 55 0 R 61 0 R 73 0 R]/Type/Pages>>\rendobj\r3 0 obj\r<</Font<</F01 13 0 R>>/ProcSet[/PDF /Text /ImageB /ImageC /ImageI]/XObject<</XIPLAYER0 6 0 R/XIPLAYER_CM1 7 0 R/XIPLAYER_CM2 9 0 R/XIPLAYER_CM3 10 0 R/XIPLAYER_CM4 11 0 R/XIPLAYER_CM5 12 0 R>>>>\rendobj\r4 0 obj\r<</Contents 5 0 R/MediaBox[0 0 842 596]/Parent 2 0 R/Resources 3 0 R/Rotate 270/Type/Page>>\rendobj\r5 0 obj\r<</Filter/FlateDecode/Length 2111>>\rstream\nx\x9c\x8dY\xdbn\x1bG\x12}\xd7W\xccK\x16\x0e \x8d\xfb~Y\xec\x8b\x14\xcb\x17\xac\x1c8\x96\x9cM\x16\x02\x02\xca\x1a\xd1LDrwHz\x01\x7f\xfdVU_f\xd83-K\x80\r\x9a>]]\x97S\xa7\xab[M\xd34\xff=i\xe8\xc7)\xd5:\x86?\rkY\xf1A{\xdf2u\xfc\xdd\x99L_}^G\x1b/\x7f{\xf7\xe1\xea\xfc\xf7\xcb\x8f\xacy\xb5\xa5\xef~\xa1\xbf\xd3\x1e\xac\x95Z\xf8f\x19\xffi\xbcn\x85\xabl)5kU\xdc]\xb7&\xc0\x94o\xad\xa9\xec\xf9\xc7O\xefym[\xe1\x8c\xcc\xdbJ\xebZU\xdb\x96+\xd3\xf2\xb0\x05g\xbeU!B\x01\xce\xf0\'6\x16\xd5\x8d\xadSyc\xc1\xe1\x0bU\xd9X\x9a\xfcIf\x98r\xae\xf5O\xec+\xeb\x01\x8ba_\xce\xfdSyN)\x95V\xa5\x8c+\xa1[W+.\xec\xab\x9e\xb7\xaf\x90-\x17\xb5DC\xbc\xc1\'m[\x13\x0b\xadt+\x9f\x08W\x0f\xd
\xaa-D\xb2\x86\x8517\xc0l\\\xb7\xec*\x91Dn\x91J\xe1\x82\x8b\x0e\xac?\xae\x96\x87\xcd\xb2R(m<\xf0\x10W\x04\xbe\xfcY#\x96\xf6.\x02C\xe3\xfc\'\xd1\xb6\xc6s\xe4\x97\xa4\xe1\xc4%~\xa1\xef\x1b`$\xb8\x13\x85p\xba\x8cS\xcfJ\x93B\xf8\xd8-W\xbb}\xd7o\x90\xf4}\xaaKI7\x90[A\x8bdd\xfd.\x99/\xb5E\x9bh>\xa4\x14\xf3\xd3E\xc5\xb2e\xd9(b\x93\x02H\xfd9\xa1\x9a\xa6c\x15\x81\xa1\xa3\xcf\xb1\xa6\x8fS\xa1\xa7`5\xc8,Z\x95\xb1\x99_\xfc\xf0c\xe5\xc0\x8b\x19\xcf\xc8\xc7\x94\xb3\xc9!n\xb8\x8eH5.{\x85\xc4\x9cX \xb5\xca\xca\xbd\xeb\x1eW@\xc9\xc5\x03\xe4y\xf7\x84\x08A\xe2\xb4\x88\x89\xcb\x9c\x9a\x86h\x04\x8e<R\xf3\xd8\xa7)D_\xf1D\x8a\xc8\xa9\xf7\x7f\xbb\xaa\xb1\x02\xc7]B\x06\x9f\xdfm\xbev\xbb\xfd\x1a\x08\xb8\x8b\xa6\'\x8c0\xb4 \xf9\xf0)\x9f\xd4e\xee\x02M%K:\xf1e\xd1\'B\x14\xedh\xe0\xf0\nCaH\xc1\xf5"S\xa78e,\x0cx\x9e\x8c\x06EYT\x15\x05S\x00\x9a&\x12\xf2\xf6\x05\x96\x01r\xbb\xbbC\x95\x08-\xf3\xd7\xfe6\x93dF\xc5\x1d\xad\x0f$\xf9p\xe8\xa1\x90\xbbJ\x04\x96a\x02\x11\x1d\x88r\xbe\xec\xbb\x0e\xb38?\xeep\xea\x1f\xc9|\x0cx4\xc6\x15\xec\xe0\x02u\x16\x91\xe9\xa8\\W\xf ...

# %%
text_all_pages = " ".join(pdf_to_text_per_page(file_content))
text_tokens = num_tokens_from_string(text_all_pages, "cl100k_base")
print("Input Text tokens: " + str(text_tokens) + " tokens")
# Out:
# Input Text tokens: 3287 tokens

# %%
print(text_all_pages)
# Out:
# UVZNr. 1666 L/2023
#
# Name, Wohnort, Geburtsda-
# tum bzw. Firma, Sitz und
# Registernummer des
# Gesellschafters
#
# M&L Investments UG
# (haftungsbeschrankt)
# mit dem Sitz in Horben,
# AG Freiburg i.Breisgau
# HRB 722284
#
# Q.E.D. Holding UG
# (haftungsbeschrankt)
#
# mit dem Sitz in Deggendorf,
# AG Deggendorf HRB 5327
#
# blume.vision UG
# (haftungsbeschrankt)
# mit dem Sitz in Hamburg,
# AG Hamburg HRB 166719
#
# ee Se
#
# Lfd. Nrn.
# Geschiaftsan-
# teile
#
# 1-2.354
#
# 5.233 —
# 10.464
#
# 25.002 —
# 25.038
#
# 10.465 —
# 15.696
#
# 25.039 —
#
# 25.041
#
# Kenn-Nr. 43890-sento GmbH/Share Sale and Puchase Agreement SB: Lime
#
# LISTE DER GESELLSCHAFTER
#
# der Firma
#
# sento GmbH
# mit dem Sitz in Miinchen,
# AG Miinchen HRB 264243
#
# Prozentuale
# Beteiligung je
# Anteil (%)
#
# Summe der Nenn-
# betrage
#
# Nennbetrag
# GeschAaftsantei-
# le
#
# 1,--€ 2.354,-- €
#
# 1,-€ 5.767,-- €
#
# Summe der
# prozentua-
# len Beteili-
# gung (%)
#
# Vermerke Uber
# Veranderungen
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
#  2,853 — 3.348
#
# Sebastian Schuon
# Investments GmbH
#
# mit dem Sitz in Grafelfing,
# Landkreis Miinchen,
#
# AG Minchen HRB 230360
#
# Void Investments UG
# (haftungsbeschrankt)
#
# AG Regensburg HRB 17445
#
# Picus Capital GmbH
# mit dem Sitz in Munchen,
# AG Minchen HRB 220147
#
# mit dem Sitz in Bad K6tzting,
#
# 15.697 —
# 16.254
#
# 25.133
#
# 3.349 — 3.410
#
# 27.728 —
# 27.771
#
# 3.411 — 3.436
#
# 16.442 -
# 24.145
#
# 25.180 —
#
# 25.844
#
# 3.437 — 4.263
#
# 1,-€
#
# 1-€
#
# 712,-- €
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# Purchase Agreement
#
# 303,-- €
#
# 9.565,-- €
#
# Purchase Agreement
#
# <1 2,00
# Share Sale and
# vom 09.06.2023
# <1 0,85
# Share Sale and
# vom 09.06.2023
# <1 26,84
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
#  Picus X3 UG
# (haftungsbeschrankt)
# mit dem Sitz in Minchen,
# AG Minchen HRB 263176
#
# Zinal Growth Partners
# Limited
#
# mit dem Sitz in Jersey,
#
# Vereinigtes Kénigreich,
# Jersey Financial Services
# Commission Nr. 134930
#
# Operator Partners LLC
#
# mit dem Sitz in Delaware,
# Vereinigte Staaten,
# Secretary of State Delaware
# Nr. 021-367799
#
# mit dem Sitz in Cayman
# Islands,
#
# Cayman Islands General
# Registry — Partnerships
#
# Charlottenburg HRB 244628 B
#
# Anselm Bauer Invest GmbH
# mit dem Sitz in Penzberg,
#
# TONA Investments L.P.
#
# Register TR 101104
# La Plata GmbH one
# mit dem Sitz in Berlin, AG 26.666
#
# 4.264 — 4.344
#
# 25.845 —
# 26.163
#
# 28.141 -—
# 28.316
# 4.345 — 4.391
#
# 26.164 —
# 26.482
#
# 28.317 —
# 28.404
# 4.392 — 4.430
#
# 26.483 —
# 26.665
#
# 4.431 -— 4.447
#
# 26.848
#
# 4.448 — 4.464
#
# 26.849 —
# 26.985
#
# 1,-€
#
# 1,--€
#
# 1,-€
#
# 1,-€
#
# 1-€
#
# 937,-- €
#
# 542,-- €
#
# 446,--€
#
# 200,-- €
#
# <1
#
# <1
#
# <1
#
# <1
#
# 2,63
#
# 1,52
#
# 0,56
#
# 0,42
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# Sitzverlegung von
# Schénefeld nach
# Berlin
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
#  Landkreis Weilheim- Share Sale and
# Schongau, 4.465 — 4.477 Purchase Agreement
# AG Minchen HRB 230392 vom 09.06.2023
#
# Benjamin Ginther Invest 26.986 —
#
# GmbH 27.122
# mit dem Sitz in Miinchen, 1--€ 150.--
# AG Manchen HRB 230764 SO € <1 0,42 [Share Sale and
# 4.478 — 4.490 Purchase Agreement
# vom 09.06.2023
# PK Projects GmbH 27.123 —
# mit dem Sitz in Berlin, 27.214
#
# AG Charlottenburg
#
# HRB 117075 B tee 101,-€ <1 0,28 Share Sale and
# 4.491 — 4.499 Purchase Agreement
#
# vom 09.06.2023
# Nominacher Ventures GmbH oe ~
# mit dem Sitz in Forstern, ,
# Landkreis Erding, rr |
# AG Miinchen HRB 193071 1-€ 101,--€ <1 0,28 | Share Sale and
# Purchase Agreement
# 4.500 — 4.508 vom 09.06.2023
#
# Belmond Capital UG
# {haftungsbeschrankt)
# mit dem Sitz in Berlin,
# AG Charlottenburg
# HRB 156383 B 4.509 — 4.512
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# Balios Capital UG 27.353 -
# (haftungsbeschrankt) 27.398
# mit dem Sitz in Berlin,
#
# AG Charlottenburg,
#
# HRB 156343 B 1,-€
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# 4513-4516
#
#  Rieke Ventures GmbH 27.399 —
# mit dem Sitz in Munchen, 27.444
# AG Minchen HRB 253508 4--€ 50,-€ <4 0.14
# ’ ' ' Share Sale and
# 4.517 — 4.520 Purchase Agreement
# vom 09.06.2023
# MADV Ventures GmbH & Co. | 27.445 -
# KG 27.490
# mit dem Sitz in Eching, 1,--€ 50,-- € <1 0,14
# Landkreis Freising, , , , Share Sale and
# AG Munchen HRA 114505 4.521 - 4.524 Purchase Agreement
# vom 09.06.2023
# Mantano Vermégensverwal- | 27.491 —
# tung UG 27.509
# (haftungsbeschrankt) 4,--€ 21,--€ <1 0,06 lene. eae
# mit dem Sitz in Kleinmachnow, , Share Sale and
# AG Potsdam HRB 34561 P 4.525 — 4.526 Purchase Agreement
# vom 09.06.2023
# PEA Ventures UG 27.510 -
# (haftungsbeschrankt) 27.528
# mit dem Sitz in Berlin,
# AG Charlottenburg 1,--€ 21,--€ <i 0,06 Share Sale and
# HRB 241401B Purchase Agreement
# 4.527 — 4.528 vom 09.06.2023
# Herr Julian Riediger,
#
# geboren am 11. Februar 1986,
# wohnhaft in Venice, CA,
# Vereinigte Staaten
#
# 21,--€ <1 0,06
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# 4.529 — 4.530
#
# Firmenanderung
# (vormals: CH & JH
# Beratungs- und
# Beteiligungsgesell-
# 1,--€ 21,--€ <4 0,06 schaft mbH)
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# sho.capital GmbH
# mit dem Sitz in Hamburg,
# AG Hamburg HRB 150804
#
# 27.548 —
#
# 4.531 — 4.532
#
#  Clear Water Bay Ventures 27.567 —
#
# GmbH 27.585
#
# mit dem Sitz in Berlin, 1-€ 24.--€ <4 0,06
#
# AG Charlottenburg , , , Share Sale and
# HRB 232752 B 4.533 — 4.534 Purchase Agreement
#
# vom 09.06.2023
#
# Muttersbach Ventures UG 27.586 —
# (haftungsbeschrankt) 27.604
# mit dem Sitz in Munchen, 1-€ 24.--€ <4 0,06
# AG Munchen HRB 190449 , , , Share Sale and
# 4.535 -— 4.536 Purchase Agreement
# vom 09.06.2023
#
# Doryfera UG 27.605 —
#
# (haftungsbeschrankt) 27.623
#
# mit dem Sitz in Weiler-
#
# Simmerberg, 1 € 21,-€ <1 0,06 Share Sale and
#
# AG Kempten (Allgau) 4.537 — 4.538 Purchase Agreement
# HRB 11806 vom 09.06.2023
# Wax Venture UG 27.624 —
#
# {haftungsbeschrankt) 27.642
#
# mit dem Sitz in Eching,
# Landkreis Freising,
# AG Munchen HRB 213094 4:539 — 4.540
#
# Riederle Investments UG 27.643 -
# (haftungsbeschrankt) 27.661
# mit dem Sitz in Minchen, 1-€
#
# AG Munchen HRB 236209
# 4.541 -— 4.542
#
# 21,--€ <1 0,06
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# <1 0,06
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# R&H Trust Co. (Jersey) Ltd. | 27 662
# as Trustee of the Siegfried | 27.680
# Trust
#
# mit dem Sitz in Jersey,
# Vereinigtes Kénigreich,
# JFSC Companies Register of
# Jersey Nr. 5661
#
# 1,-€
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# 4.543 - 4.544
#
# Herr Matthew Jack
# Robinson, 27.681 —
#
#  geboren am 15. August 1987,
# wohnhaft in London,
# Vereinigtes K6nigreich
#
# 27.699
#
# 4.545 — 4.546
#
# Herr Alexander Hersham,
# geboren am 15. August 1986,
#
# 27.700 -
# 27.718
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# wohnhaft in London, <1 0,06
# Vereinigtes Kénigreich ‘ Share Sale and
# 4.547 — 4.548 Purchase Agreement
#
# vom 09.06.2023
#
# Insight Luxembourg Xil 28.405 -
#
# S.ar.l. 35.216
#
# mit dem Sitz in Luxemburg,
#
# Handels- und Gesellschaftsre- 1€ 7.487,— <1 20,92 Share Sale and
#
# gister Luxemburg 4.549 — 5.193 Purchase Agreement
#
# Nr. B255793 vom 09.06.2023
#
# Discovery Ventures Ill GmbH | 35.217 —
#
# & Co. KG 35.568
#
# mit dem Sitz in Berlin, <4 1,08
#
# AG Charlottenburg , Share Sale and
#
# HRA 59004 B 5.194 — 5.226 Purchase Agreement
# vom 09.06.2023
#
# Herr Miguel Eduardo 35.569 —
#
# Burger, 35.594
#
# geboren am
#
# 7 Dezember 1986, 1-€ 28,-- € <1 0,08 Share Sale and
#
# Brooklyn, New York, 5.227 — 5.228 vom 03.06.2023.
#
# Vereinigte Staaten
#
# Se9tember Tech Ventures 35.595 —
#
# UG (haftungsbeschrankt) 35.616
#
# mit dem Sitz in Berlin
#
# , 1-€ 24,--€ <1
#
# AG Charlottenburg Share Sale and
#
# HRB 234235 B 5.229 — 5.230 Purchase Agreement
# vom 09.06.2023
#
# Herr Torben Wolf,
#
# geboren am 25. Oktober 1989, 1-€ 24, €
#
#  wohnhaft in Ludwigsburg
#
# Share Sale and
# Purchase Agreement
# vom 09.06.2023
#
# 5.231 — 5.232
#
# Summe: 35.638,-- €
#
# —_
# io
#
# Die geanderten Eintragungen in der vorstehenden Liste entsprechen den Veranderungen, die sich aufgrund meiner Urkunde vom 09.06.2023,
# UVZNr. 1052 L/2023, ergeben. Die Ubrigen Eintragungen stimmen mit dem Inhalt der zuletzt im Handelsregister aufgenommenen Liste vom 05.07.2022
# iberein.
#
# Munchen, den 18.09.2023
#
# Yt =
# 5 WY
# f NAL ft Z
# Comce
# Konrad Lautner, Notar
#
#  Hiermit beglaubige ich die Ubereinstimmung der in dieser Datei enthaltenen Bilddaten (Abschrift)
#
# mit dem mir vorliegenden Papierdokument (Urschrift).
#
# Munchen, den 21.09.2023
#
# Konrad Lautner, Notar

# %%
# import PyPDF2

# reader = PyPDF2.PdfReader("/Users/annabellschafer/Desktop/GitHub/cr_exploration/notebooks/output/"+file_name)
# number_of_pages = len(reader.pages)
# text =""
# for page in reader.pages:
#    text = text + page.extract_text() 

# print(text)
# Out:
#
# Dok-ID 217071
# Akte: 2023 -1282 N  Liste der Gesellschafter der
#
# SUMM AI GmbH
#
# mit Sitz in München
# Amtsgericht München, HRB 275514
#
# Vor- und Nachname des Gesellschafters,
# Geburtsdatum, Wohnort bzw. Firma, Registernr.
# u. Amtsgericht, Sitz  lfd. Nummer  Nennbetrag der
# Geschäftsanteile  prozentualer An-
# teil des Ges-
# chäftsanteiles am
# Stammkapital  Summe der
# Nennbeträge des
# Gesellschafters  prozentualer An-
# teil des
# Gesamtumfangs
# der Geschäftsan-
# teile am Stam-
# mkapital  Veränderung
# floral ventures UG (haftungsbeschränkt)
# AG Hamburg HRB 175232
# Hamburg  1 - 8.334  je 1,00 €  je 0,0031%  8.334,00 €  26,23%
# Dataflow Ventures UG (haftungsbeschränkt)
# AG Schweinfurt HRB 8953
# Burkardroth  8.335 -
# 16.668  je 1,00 €  je 0,0031%  8.334,00 €  26,23%
# WHY NOT adVentures UG (haftungsbeschränkt)
# AG München HRB 275415
# München  16.669 -
# 25.002  je 1,00 €  je 0,0031%  8.334,00 €  26,23%
# Uhlig Capital GmbH
# AG München HRB 226493
# München  25.003 -
# 25.128  je 1,00 €  je 0,0031%  126,00 €  0,3965%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# COre -invest GmbH
# AG Nürnberg HRB 30442
# Nürnberg  25.129 -
# 26.538  je 1,00 €  je 0,0031%  1.410,00 €  4,44%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# SKR Capital GmbH
# AG Frankfurt am Main HRB 100589
# Frankfurt am Main  26.539 -
# 27.713  je 1,00 €  je 0,0031%  1.175,00 €  3,7%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# Seite 2 von 3
# Dok-ID 217071
# Akte: 2023 -1282 N  Venture Stars Beteiligungsgesellschaft III GmbH
# & Co. KG
# AG München HRA 115261
# München  27.714 -
# 30.532  je 1,00 €  je 0,0031%  2.819,00 €  8,87%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# NJ Ventures GmbH
# AG München HRB 275120
# München  30.533 -
# 30.649  je 1,00 €  je 0,0031%  117,00 €  0,3682%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# Campione Ventures UG (haftungsbeschränkt)
# AG Köln HRB 89795
# Köln 30.650 -
# 30.743  je 1,00 €  je 0,0031%  94,00 €  0,2958%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# Herr Johann Theodor Pastor
# geb. am 11.08.1960
# wohnhaft Schliersee  30.744 -
# 31.025  je 1,00 €  je 0,0031%  282,00 €  0,8875%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# Rowing8 AG
# Handelsreg isteramt des Kantons Zug
# CHE354.314.731
# Zug, Schweiz  31.026 -
# 31.072  je 1,00 €  je 0,0031%  47,00 €  0,1479%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# Unlost GmbH
# AG Frankfurt am Main HRB 125404
# Frankfurt am Main  31.073 -
# 31.189  je 1,00 €  je 0,0031%  117,00 €  0,3682%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# Richard Foster GmbH
# AG München HRB 154426
# München  31.190 -
# 31.306  je 1,00 €  je 0,0031%  117,00 €  0,3682%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# jvh-ventures GmbH
# AG Nürnberg HRB 29574
# Simmelsdorf  31.307 -
# 31.541  je 1,00 €  je 0,0031%  235,00 €  0,7396%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# Superangels Management GmbH
# AG München HRB 283677
# München  31.542 -
# 31.776  je 1,00 €  je 0,0031%  235,00 €  0,7396%  neu geschaffen im
# Wege der Kapital-
# erhöhung
# Seite 3 von 3
# Dok-ID 217071
# Akte: 2023 -1282 N
#
# Ich bescheinige hiermit, dass die vorstehende Gesellschafterliste den Veränderungen entspricht, an denen ich durch meine Urku nde vom  6. Oktober
# 2023 , UVZ -Nr. 573/2023 H , mitgewirkt habe, und dass die übrigen Angaben in der Liste mit dem Inhalt der zuletzt beim Handelsregister aufgenom-
# menen Liste übereinstimmen.  Die Änderungen werden mit Eintragung der Kapitalerhöhung in das Handelsregister wirksam.
#
# Berlin , den 6. Oktober 2023
#
#
# Dr. Oliver Hüfner
# Notar  Stammkapital:  31.776,00 €

# %%
import json
# text_all_pages = text
response_message = get_structured_shareholder_list(text_all_pages, file_name[:-4])
shareholders_object = json.loads(response_message.tool_calls[0].function.arguments)
shareholders_list = shareholders_object["shareholders"]

# %%
#add company column
df_temp = pd.DataFrame(shareholders_list)
file_name = file_name[:-4]
df_temp['company'] = file_name

# %%
#add df to exiting df as additional values
df = df.append(df_temp, ignore_index=True)
# Out:
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/1569727871.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)

# %%
df
# Out:
#                                                 name  \
# 0          FYS Ventures UG (haftungsbeschr\u00e4nkt)
# 1                            Tanso Technologies GmbH
# 2    Wiechmann Ventures UG (haftungsbeschr\u00e4nkt)
# 3         Gyri Ventures UG (haftungsbeschr\u00e4nkt)
# 4       Hetzel Ventures UG (haftungsbeschr\u00e4nkt)
# ..                                               ...
# 206                   Insight Luxembourg Xil S.ar.l.
# 207             Discovery Ventures Ill GmbH & Co. KG
# 208                       Herr Miguel Eduardo Burger
# 209  September Tech Ventures UG (haftungsbeschrankt)
# 210                                 Herr Torben Wolf
#
#                                       registry_details            location  \
# 0                          AG M\u00fcnchen, HRB 268779        M\u00fcnchen
# 1                          AG M\u00fcnchen, HRB 269123        M\u00fcnchen
# 2                          AG M\u00fcnchen, HRB 268778        M\u00fcnchen
# 3                          AG M\u00fcnchen, HRB 268777        M\u00fcnchen
# 4                        AG D\u00fcsseldorf, HRB 94685     D\u00fcsseldorf
# ..                                                 ...                 ...
# 206  Handels- und Gesellschaftsregister Luxemburg N...           Luxemburg
# 207                      AG Charlottenburg HRA 59004 B              Berlin
# 208                                                NaN  Brooklyn, New York
# 209                     AG Charlottenburg HRB 234235 B              Berlin
# 210                                                NaN         Ludwigsburg
#
#      nominal_value_per_share  total_nominal_value participation_per_share  \
# 0                          1               1110.0                0.0021 %
# 1                          1               6973.0                0.0021 %
# 2                          1               8083.0                0.0021 %
# 3                          1               8083.0                0.0021 %
# 4                          1                751.0                0.0021 %
# ..                       ...                  ...                     ...
# 206                        1               7487.0                     NaN
# 207                        1                  1.0                     NaN
# 208                        1                 28.0                     NaN
# 209                        1                 24.0                     NaN
# 210                        1                 24.0                     NaN
#
#     total_participation_in_percent date_of_birth                    company
# 0                           2.34 %           NaN  Tacto Technology GmbH_Mün
# 1                          14.73 %           NaN  Tacto Technology GmbH_Mün
# 2                          17.07 %           NaN  Tacto Technology GmbH_Mün
# 3                          17.07 %           NaN  Tacto Technology GmbH_Mün
# 4                           1.59 %           NaN  Tacto Technology GmbH_Mün
# ..                             ...           ...                        ...
# 206                       <1 20,92           NaN             sento GmbH_Mün
# 207                        <1 1,08           NaN             sento GmbH_Mün
# 208                        <1 0,08           NaN             sento GmbH_Mün
# 209                        <1 0,08           NaN             sento GmbH_Mün
# 210                        <1 0,08           NaN             sento GmbH_Mün
#
# [211 rows x 9 columns]

# %%
# safe df as csv
df.to_csv('shareholders_list.csv', index=False)

# %% [markdown]
# ## All in one function

# %%
df = pd.DataFrame()

#open csv with company names
companies = pd.read_csv('initial_hundred.csv', header=None)
companies = companies[0].tolist()
#take the first 30 companies, remove first row
companies = companies[0:100]
print(companies)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 df = pd.DataFrame()
#       3 #open csv with company names
# ----> 4 companies = pd.read_csv('initial_hundred.csv', header=None)
#       5 companies = companies[0].tolist()
#       6 #take the first 30 companies, remove first row
#
# File ~/Documents/Github/cr-exploration/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/Github/cr-exploration/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/Documents/Github/cr-exploration/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/Github/cr-exploration/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/Documents/Github/cr-exploration/.venv/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'initial_hundred.csv'

# %%
#loop over companies to retrieve their documents and store them in a dataframe

def get_shareholder_table_for_companies(companies: list, document_type: str):
    df = pd.DataFrame()
    for company in companies:
        try:
            file_name, file_content = get_pdf_for_company(company, document_type, True)
            text_all_pages = " ".join(pdf_to_text_per_page(file_content))
            response_message = get_structured_shareholder_list(text_all_pages, file_name)
            print(file_name)
            shareholders_object = json.loads(response_message.tool_calls[0].function.arguments)
            shareholders_list = shareholders_object["shareholders"]
            df_temp = pd.DataFrame(shareholders_list)
            file_name = file_name[:-4]
            df_temp['company'] = file_name
            print(file_name)
            df = df.append(df_temp, ignore_index=True)
        except Exception as e:
            print("Error for company: " + company)
            print(str(e))
    return df

result = get_shareholder_table_for_companies(companies, 'gs')
result.to_csv('shareholders_list.csv', index=False)
# Out:
# ACTIMI GmbH_Stuttgart.pdf
# ACTIMI GmbH_Stuttgart
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: EcoPals GmbH
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# alfatier GmbH_Hamburg.pdf
# alfatier GmbH_Hamburg
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Dealcode GmbH_Hamburg.pdf
# Dealcode GmbH_Hamburg
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Milkly GmbH_Hamburg.pdf
# Milkly GmbH_Hamburg
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Unstoppable Finance GmbH_Berlin (Charlottenburg).pdf
# Unstoppable Finance GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 500
# Error for company: Betriebsmittelhelden
# cannot unpack non-iterable NoneType object
# MicroHarvest GmbH_Hamburg.pdf
# MicroHarvest GmbH_Hamburg
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Noyes Technologies GmbH_München.pdf
# Noyes Technologies GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Countercheck GmbH_Berlin (Charlottenburg).pdf
# Countercheck GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 502
# Error for company: The Exploration Company
# cannot unpack non-iterable NoneType object
# Elixion Medical GmbH_Düsseldorf.pdf
# Elixion Medical GmbH_Düsseldorf
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: Content Bay
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Hopper Mobility GmbH_Augsburg.pdf
# Hopper Mobility GmbH_Augsburg
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# SOLAR MATERIALS GmbH_Stendal.pdf
# SOLAR MATERIALS GmbH_Stendal
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 500
# Error for company: AeroSys
# cannot unpack non-iterable NoneType object
# Software Defined Automation GmbH_München.pdf
# Software Defined Automation GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# MARA Solutions GmbH_Mannheim.pdf
# MARA Solutions GmbH_Mannheim
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Elona Health GmbH_Düsseldorf.pdf
# Elona Health GmbH_Düsseldorf
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Coinformation GmbH_Düsseldorf.pdf
# Coinformation GmbH_Düsseldorf
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# An error occurred during orientation detection: (1, 'Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Fusion Bionic GmbH_Dresden.pdf
# Fusion Bionic GmbH_Dresden
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 404
# Error for company: Passionfroot
# cannot unpack non-iterable NoneType object
# Atlas Metrics GmbH_Berlin (Charlottenburg).pdf
# Atlas Metrics GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Sub Capitals GmbH_München.pdf
# Sub Capitals GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Hoaly Foods GmbH_München.pdf
# Hoaly Foods GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# BUILD & CODE GmbH_Potsdam.pdf
# BUILD & CODE GmbH_Potsdam
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# REFLEX aerospace GmbH_München.pdf
# REFLEX aerospace GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Additive Scale GmbH_München.pdf
# Additive Scale GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Capreolos GmbH_Frankfurt am Main.pdf
# Capreolos GmbH_Frankfurt am Main
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# RAMPmedical GmbH_Berlin (Charlottenburg).pdf
# RAMPmedical GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: VISIONME GmbH
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error for company: Zana Technologies GmbH
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Error for company: New Solutions GmbH
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# iotis GmbH_Hannover.pdf
# iotis GmbH_Hannover
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Briink Intelligence GmbH_Berlin (Charlottenburg).pdf
# Briink Intelligence GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Freshflow GmbH_Berlin (Charlottenburg).pdf
# Freshflow GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Onstruc UG (haftungsbeschränkt)_Berlin (Charlottenburg).pdf
# Onstruc UG (haftungsbeschränkt)_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 500
# Error for company: Priv
# cannot unpack non-iterable NoneType object
# Cryptoticker.io GmbH_Berlin (Charlottenburg).pdf
# Cryptoticker.io GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Voltfang GmbH_Aachen.pdf
# Voltfang GmbH_Aachen
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 500
# Error for company: Dance
# cannot unpack non-iterable NoneType object
# greenforce Beteiligungsgesellschaft mbH_Bad Oeynhausen.pdf
# greenforce Beteiligungsgesellschaft mbH_Bad Oeynhausen
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Casculate GmbH_Kaiserslautern.pdf
# Casculate GmbH_Kaiserslautern
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: Hive
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Urbyo GmbH_Berlin (Charlottenburg).pdf
# Urbyo GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 500
# Error for company: resonanz energy
# cannot unpack non-iterable NoneType object
# Yababa GmbH_Berlin (Charlottenburg).pdf
# Yababa GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Recunited GmbH_Berlin (Charlottenburg).pdf
# Recunited GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# igetnow GmbH_Kiel.pdf
# igetnow GmbH_Kiel
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Packmatic GmbH_Berlin (Charlottenburg).pdf
# Packmatic GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: CURE
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Failed to retrieve PDF: Status code 500
# Error for company: Composable Finance
# cannot unpack non-iterable NoneType object
# Beautinda GmbH_Essen.pdf
# Beautinda GmbH_Essen
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 500
# Error for company: Share
# cannot unpack non-iterable NoneType object
# Failed to retrieve PDF: Status code 500
# Error for company: Vay
# cannot unpack non-iterable NoneType object
# Beamer & more GmbH_Stuttgart.pdf
# Beamer & more GmbH_Stuttgart
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: Actio
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (48): Illegal character <1a> in hex string
# Syntax Error (49): Illegal character <a5> in hex string
# Syntax Error (50): Illegal character <aa> in hex string
# Syntax Error (51): Illegal character <1c> in hex string
# Syntax Error (53): Illegal character <40> in hex string
# Syntax Error (54): Illegal character <ac> in hex string
# Syntax Error (55): Illegal character <74> in hex string
# Syntax Error (56): Illegal character <3a> in hex string
# Syntax Error (57): Illegal character <d9> in hex string
# Syntax Error (58): Illegal character <a2> in hex string
# Syntax Error (59): Illegal character <1d> in hex string
# Syntax Error (60): Illegal character <0e> in hex string
# Syntax Error (61): Illegal character <06> in hex string
# Syntax Error (63): Illegal character <1d> in hex string
# Syntax Error (64): Illegal character <40> in hex string
# Syntax Error (66): Illegal character <b5> in hex string
# Syntax Error (68): Illegal character <4e> in hex string
# Syntax Error (69): Illegal character <87> in hex string
# Syntax Error (71): Illegal character <a1> in hex string
# Syntax Error (72): Illegal character <c3> in hex string
# Syntax Error (75): Illegal character <8e> in hex string
# Syntax Error (76): Illegal character <87> in hex string
# Syntax Error (77): Illegal character <4b> in hex string
# Syntax Error (78): Illegal character <8b> in hex string
# Syntax Error (79): Illegal character <e3> in hex string
# Syntax Error (80): Illegal character <86> in hex string
# Syntax Error (81): Illegal character <48> in hex string
# Syntax Error (82): Illegal character <2e> in hex string
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Failed to retrieve PDF: Status code 500
# Error for company: MAYD
# cannot unpack non-iterable NoneType object
# MIL-KABEL-SYSTEMS GmbH_Ulm.pdf
# MIL-KABEL-SYSTEMS GmbH_Ulm
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Event Management Gesellschaft für Freizeit- & Veranstaltungsorganisation GmbH_Freiburg.pdf
# Event Management Gesellschaft für Freizeit- & Veranstaltungsorganisation GmbH_Freiburg
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Payla Services GmbH_München.pdf
# Payla Services GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Mondu GmbH_Berlin (Charlottenburg).pdf
# Mondu GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# flowplace GmbH_Leipzig.pdf
# flowplace GmbH_Leipzig
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Atheneum Partners GmbH_Berlin (Charlottenburg).pdf
# Atheneum Partners GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# x-cardiac GmbH_Berlin (Charlottenburg).pdf
# x-cardiac GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: BITA
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Failed to retrieve PDF: Status code 500
# Error for company: Pectus Finance
# cannot unpack non-iterable NoneType object
# Error for company: Ryte
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# CYCLE Sport-Handels-GmbH_Stuttgart.pdf
# CYCLE Sport-Handels-GmbH_Stuttgart
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: ARIVE
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Tupu Farming Solutions GmbH_Berlin (Charlottenburg).pdf
# Tupu Farming Solutions GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Hivebuy GmbH_Berlin (Charlottenburg).pdf
# Hivebuy GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# SQUAKE.earth GmbH_Berlin (Charlottenburg).pdf
# SQUAKE.earth GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# GRID Invest GmbH_Hamburg.pdf
# GRID Invest GmbH_Hamburg
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# eleva GmbH_Stuttgart.pdf
# eleva GmbH_Stuttgart
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# MAIT GmbH_Offenbach am Main.pdf
# MAIT GmbH_Offenbach am Main
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Capabox GmbH_Berlin (Charlottenburg).pdf
# Capabox GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Circula GmbH_Berlin (Charlottenburg).pdf
# Circula GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 500
# Error for company: Raus
# cannot unpack non-iterable NoneType object
# Finanzchef24 GmbH_München.pdf
# Finanzchef24 GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Upminster GmbH_Frankfurt am Main.pdf
# Upminster GmbH_Frankfurt am Main
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 500
# Error for company: AVA
# cannot unpack non-iterable NoneType object
# Error for company: Optalio
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Failed to retrieve PDF: Status code 500
# Error for company: deineStudienfinanzierung
# cannot unpack non-iterable NoneType object
# touch smoke GmbH_Ulm.pdf
# touch smoke GmbH_Ulm
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Elopage GmbH_Berlin (Charlottenburg).pdf
# Elopage GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# FinanzRitter GmbH_Iserlohn.pdf
# FinanzRitter GmbH_Iserlohn
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Failed to retrieve PDF: Status code 500
# Error for company: Transolt
# cannot unpack non-iterable NoneType object
# Triviar Education GmbH_Hamburg.pdf
# Triviar Education GmbH_Hamburg
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# LODGEA GmbH_München.pdf
# LODGEA GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: ryd
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error (21): Illegal character ')'
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Friday Finance GmbH_Berlin (Charlottenburg).pdf
# Friday Finance GmbH_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Charge & More Entwicklungs- und Servicegesellschaft für Elektromobilität UG (haftungsbeschränkt)_Berlin (Charlottenburg).pdf
# Charge & More Entwicklungs- und Servicegesellschaft für Elektromobilität UG (haftungsbeschränkt)_Berlin (Charlottenburg)
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# bitsCrunch GmbH_München.pdf
# bitsCrunch GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: Aware
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Helsing Germany GmbH_München.pdf
# Helsing Germany GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)
# Error for company: tink
# Unable to get page count.
# Syntax Warning: May not be a PDF file (continuing anyway)
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't find trailer dictionary
# Syntax Error: Couldn't read xref table
#
# Failed to retrieve PDF: Status code 500
# Error for company: re cap
# cannot unpack non-iterable NoneType object
# ZenML GmbH_München.pdf
# ZenML GmbH_München
# /var/folders/nw/rzxfctl55nj95y0twwbqxrm40000gn/T/ipykernel_18231/3005934300.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_temp, ignore_index=True)

# %%
# import PyPDF2

# # Open the PDF file in binary mode
# with open('errors.pdf', 'rb') as file:
#     # Create a PDF file reader object
#     pdf_reader = PyPDF2.PdfReader(file)

#     # Initialize an empty string to hold the text
#     text = ''

#     # Loop through each page in the PDF and extract the text
#     for page_num in range(len(pdf_reader.pages)):
#         page = pdf_reader.pages[page_num]
#         text += page.extract_text()

# # Now 'text' contains the text extracted from the PDF
# print(text)
# Out:
# ---------------------------------------------------------------------------NameError                                 Traceback (most recent call last)/Users/annabellschafer/Desktop/GitHub/cr_exploration/notebooks/e2e_retrieve_file_get_shareholder_Niklas.ipynb Cell 11 line 2      1 # sum up the total participation in percent for all shareholders----> 2 total_participation_in_percent = sum([shareholder["total_participation_in_percent"] for shareholder in shareholders["shareholders"]])      3 total_participation_in_percentNameError: name 'shareholders' is not defined0.0032259999999999997Input Text tokens: 3287 tokensnameregistry_detailslocationnominal_value_per_sharetotal_nominal_valueparticipation_per_sharetotal_participation_in_percentdate_of_birthcompany0FYS Ventures UG (haftungsbeschr\u00e4nkt)AG M\u00fcnchen, HRB 268779M\u00fcnchen11110.00.0021 %2.34 %NaNTacto Technology GmbH_Mün1Tanso Technologies GmbHAG M\u00fcnchen, HRB 269123M\u00fcnchen16973.00.0021 %14.73 %NaNTacto Technology GmbH_Mün2Wiechmann Ventures UG (haftungsbeschr\u00e4nkt)AG M\u00fcnchen, HRB 268778M\u00fcnchen18083.00.0021 %17.07 %NaNTacto Technology GmbH_Mün3Gyri Ventures UG (haftungsbeschr\u00e4nkt)AG M\u00fcnchen, HRB 268777M\u00fcnchen18083.00.0021 %17.07 %NaNTacto Technology GmbH_Mün4Hetzel Ventures UG (haftungsbeschr\u00e4nkt)AG D\u00fcsseldorf, HRB 94685D\u00fcsseldorf1751.00.0021 %1.59 %NaNTacto Technology GmbH_Mün..............................206Insight Luxembourg Xil S.ar.l.Handels- und Gesellschaftsregister Luxemburg N...Luxemburg17487.0NaN<1 20,92NaNsento GmbH_Mün
bb}\xd7o\x90\xf4}\xaaKI7\x90[A\x8bdd\xfd.\x99/\xb5E\x9bh>\xa4\x14\xf3\xd3E\xc5\xb2e\xd9(b\x93\x02H\xfd9\xa1\x9a\xa6c\x15\x81\xa1\xa3\xcf\xb1\xa6\x8fS\xa1\xa7`5\xc8,Z\x95\xb1\x99_\xfc\xf0c\xe5\xc0\x8b\x19\xcf\xc8\xc7\x94\xb3\xc9!n\xb8\x8eH5.{\x85\xc4\x9cX \xb5\xca\xca\xbd\xeb\x1eW@\xc9\xc5\x03\xe4y\xf7\x84\x08A\xe2\xb4\x88\x89\xcb\x9c\x9a\x86h\x04\x8e<R\xf3\xd8\xa7)D_\xf1D\x8a\xc8\xa9\xf7\x7f\xbb\xaa\xb1\x02\xc7]B\x06\x9f\xdfm\xbev\xbb\xfd\x1a\x08\xb8\x8b\xa6\'\x8c0\xb4 \xf9\xf0)\x9f\xd4e\xee\x02M%K:\xf1e\xd1\'B\x14\xedh\xe0\xf0\nCaH\xc1\xf5"S\xa78e,\x0cx\x9e\x8c\x06EYT\x15\x05S\x00\x9a&\x12\xf2\xf6\x05\x96\x01r\xbb\xbbC\x95\x08-\xf3\xd7\xfe6\x93dF\xc5\x1d\xad\x0f$\xf9p\xe8\xa1\x90\xbbJ\x04\x96 ...

# %%
import re

# Sample text

# Regular expression pattern to match 'error:' followed by any 15 characters
pattern = r'Error.{0,70}'

# Use re.findall to find all substrings that match the pattern
error_substrings = re.findall(pattern, text)

# Print the list of error substrings
for substring in error_substrings:
    print(substring)
# Out:
# Error                                 Traceback (most recent call last)/Use
# Error: name 'shareholders' is not defined0.0032259999999999997Input Text to
# Error for company: SyncRealitycannot unpack non-iterable NoneType objectiot
# Error for company: Yunex Trafficcannot unpack non-iterable NoneType objectB
# Error for company: Bestgameprice.netcannot unpack non-iterable NoneType obj
# Error for company: padoUnable to get page count.Syntax Warning: May not be
# Error: Couldn't find trailer dictionarySyntax Error: Couldn't find trailer
# Error: Couldn't read xref tableFreshflow GmbH_Berlin (Charlottenburg).pdf
# Error for company: RecareUnable to get page count.Syntax Warning: May not b
# Error: Couldn't find trailer dictionarySyntax Error: Couldn't find trailer
# Error: Couldn't read xref tablewildplastic GmbH_Hamburg.pdf
# Error for company: Agrivero.aicannot unpack non-iterable NoneType objectErr
# Error: Couldn't find trailer dictionarySyntax Error: Couldn't find trailer
# Error: Couldn't read xref tableFailed to retrieve PDF: Status code 500Error
# Error for company: Privcannot unpack non-iterable NoneType objectrubarb Gmb
# Error for company: AssemblyUnable to get page count.Syntax Warning: May not
# Error: Couldn't find trailer dictionarySyntax Error: Couldn't find trailer
# Error: Couldn't read xref tableeGym GmbH_München.pdf
# Error for company: Mosaeekcannot unpack non-iterable NoneType objectPlanBlu
# Error for company: SellerX'shareholders'billi & friends Wohnkaufhaus GmbH_K
# Error for company: Celoniscannot unpack non-iterable NoneType objectFailed
# Error for company: wewavecannot unpack non-iterable NoneType objectAleph Al
# Error for company: Meine Erdecannot unpack non-iterable NoneType objectEnpa
# Error for company: Tomorrowcannot unpack non-iterable NoneType objectYepoda
